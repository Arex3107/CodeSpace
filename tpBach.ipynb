# %% [markdown]
# # 1 Affichez le dossier courant
#
# # 2 Renomer dans le répertoire /home/vscode
#
# # 3 Créer un dossier miniTP dans ce répertoire
#
# # 4 Affichez le contenu de tous les fichiers ou dossiers présents
#
# # 5 Créer un fichier vide notes.txt
#
# # 6 Ajoutez dans ce fichier la ligne "Linux is powerfull"
#
# # 7 renomer
#
# #
